# %%
import os
filepath='C:\Users\IVAN\Desktop\evoBoids\evoBoids Code'
os.chdir(filepath)

# %run evoBoids.py
# Out:
# Do you want to load a SeedPopuation: [1:Yes ; 0:No]0
#
# Estimated Evolution time: 10500.000000 s  ... Press Enter to continue ...
#
# 9.66037735849
# 6.28260869565
# 7.30434782609
# 0.0
# 0.0
# 0.0
# 3.453125
# 4.5
# 5.0
# 1.51111111111
# 1.2
# 2.08823529412
# 1.29166666667
# 1.58333333333
# 1.60975609756
# 8.5
# 6.78723404255
# 8.39583333333
# 0.0
# 1.0
# 0.0
# 1.6862745098
# 1.7037037037
# 2.01886792453
# 1.65573770492
# 1.54385964912
# 1.18644067797
# 3.05357142857
# 3.16071428571
# 3.40677966102
# Generation No. : 0
# 8.56862745098
# 8.51351351351
# 8.17021276596
# 7.80392156863
# 9.22448979592
# 9.97916666667
# 1.41818181818
# 1.52542372881
# 1.74576271186
# 2.95
# 3.29032258065
# 2.85714285714
# 1.63636363636
# 1.4262295082
# 1.86206896552
# 2.76744186047
# 2.84615384615
# 2.24528301887
# 6.12727272727
# 4.87272727273
# 6.62745098039
# 5.46808510638
# 5.65384615385
# 5.64814814815
# 1.71698113208
# 1.53571428571
# 1.52727272727
# 4.61904761905
# 4.14285714286
# 4.55555555556
# Generation No. : 1
# 8.7962962963
# 8.18518518519
# 8.75471698113
# 2.24590163934
# 2.08196721311
# 1.98360655738
# 3.41176470588
# 3.02083333333
# 3.20930232558
# 1.48148148148
# 1.36666666667
# 1.46296296296
# 3.38636363636
# 3.02222222222
# 3.68085106383
# 1.38596491228
# 1.15789473684
# 1.61403508772
# 5.08333333333
# 4.53191489362
# 4.68888888889
# 4.72727272727
# 3.78571428571
# 5.14285714286
# 4.95
# 4.95
# 4.65
# 3.125
# 2.8813559322
# 3.16071428571
# Generation No. : 2
# 1.58928571429
# 1.64912280702
# 1.48
# 2.53703703704
# 3.2037037037
# 3.38
# 1.58620689655
# 1.35593220339
# 1.51612903226
# 3.90163934426
# 3.73770491803
# 3.69491525424
# 4.64406779661
# 4.25423728814
# 4.28333333333
# 1.87719298246
# 1.41509433962
# 2.0
# 3.64150943396
# 3.33962264151
# 3.44230769231
# 4.46296296296
# 3.96610169492
# 4.81355932203
# 5.01666666667
# 5.28333333333
# 5.39344262295
# 1.27868852459
# 1.2131147541
# 0.932203389831
# Generation No. : 3
# 4.22950819672
# 4.16363636364
# 4.2
# 4.08771929825
# 4.27586206897
# 4.50943396226
# 3.68852459016
# 3.62745098039
# 3.58695652174
# 3.48076923077
# 3.08771929825
# 3.84905660377
# 1.55357142857
# 1.58928571429
# 1.30357142857
# 4.21153846154
# 4.28571428571
# 4.15384615385
# 1.80769230769
# 1.7037037037
# 1.41666666667
# 3.43859649123
# 4.09615384615
# 3.32727272727
# 4.23076923077
# 4.50943396226
# 4.76785714286
# 3.62068965517
# 3.83050847458
# 3.77777777778
# Generation No. : 4
# 4.27272727273
# 4.26923076923
# 4.69642857143
# 3.92156862745
# 3.11111111111
# 3.0
# 3.55813953488
# 3.63829787234
# 3.31578947368
# 3.5
# 3.37037037037
# 3.86538461538
# 1.6
# 2.16071428571
# 2.16666666667
# 0.0
# 5.48837209302
# 0.0
# 0.732142857143
# 0.709090909091
# 0.705882352941
# 4.91666666667
# 4.51020408163
# 4.2619047619
# 4.75471698113
# 4.12068965517
# 4.1186440678
# 4.75
# 4.44827586207
# 3.98245614035
# Generation No. : 5
# 4.23728813559
# 4.6935483871
# 4.26666666667
# 2.01923076923
# 1.81355932203
# 1.85
# 3.73770491803
# 3.53571428571
# 3.48214285714
# 3.36842105263
# 3.62068965517
# 3.86206896552
# 3.87719298246
# 3.66666666667
# 3.59016393443
# 4.95
# 4.83606557377
# 5.29508196721
# 0.0
# 0.0
# 2.37142857143
# 3.91379310345
# 3.65
# 3.68965517241
# 4.89473684211
# 4.57894736842
# 3.93333333333
# 3.68852459016
# 3.86885245902
# 3.80327868852
# Generation No. : 6
# 4.82142857143
# 5.36666666667
# 4.78571428571
# 3.34426229508
# 3.26785714286
# 3.94915254237
# 3.89473684211
# 3.90909090909
# 3.78947368421
# 0.774193548387
# 0.916666666667
# 0.793103448276
# 3.75
# 3.75438596491
# 3.81034482759
# 4.84482758621
# 4.91666666667
# 4.375
# 0.0
# 0.0
# 0.0
# 3.79310344828
# 3.64788732394
# 3.53846153846
# 3.8813559322
# 3.20930232558
# 3.82142857143
# 3.92727272727
# 2.95744680851
# 3.79245283019
# Generation No. : 7
# 5.03703703704
# 5.66666666667
# 4.8813559322
# 3.88524590164
# 3.81967213115
# 3.3
# 3.64814814815
# 3.79310344828
# 3.21052631579
# 3.38596491228
# 3.59574468085
# 3.20754716981
# 4.67272727273
# 4.92857142857
# 5.88679245283
# 3.875
# 3.71186440678
# 3.19298245614
# 0.769230769231
# 0.822222222222
# 0.714285714286
# 0.0
# 5.61290322581
# 0.0
# 3.6724137931
# 3.38888888889
# 3.55555555556
# 3.31034482759
# 3.32692307692
# 4.28571428571
# Generation No. : 8
# 0.762711864407
# 0.603448275862
# 0.694915254237
# 3.75
# 3.63157894737
# 3.59649122807
# 3.75
# 3.09090909091
# 3.64406779661
# 3.96666666667
# 3.79661016949
# 3.4
# 4.08620689655
# 3.98245614035
# 3.77966101695
# 3.96610169492
# 3.85
# 3.42857142857
# 3.21666666667
# 3.23333333333
# 3.91803278689
# 3.98076923077
# 5.38
# 3.89795918367
# 2.97297297297
# 4.78125
# 6.0
# 4.63636363636
# 4.34545454545
# 4.47368421053
# Generation No. : 9
# 0.0
# 4.09302325581
# 5.61363636364
# 4.77586206897
# 4.50980392157
# 3.92727272727
# 3.09090909091
# 3.30188679245
# 3.25490196078
# 3.56140350877
# 3.84615384615
# 3.71111111111
# 3.62264150943
# 3.01785714286
# 3.79591836735
# 3.54385964912
# 4.26785714286
# 4.63461538462
# 4.59259259259
# 4.625
# 4.58490566038
# 3.12962962963
# 3.14285714286
# 3.21052631579
# 1.3
# 1.21818181818
# 1.30769230769
# 3.69642857143
# 2.89090909091
# 3.59183673469
# Generation No. : 10
# 3.65909090909
# 3.625
# 3.64444444444
# 3.86538461538
# 3.64814814815
# 3.92156862745
# 3.38775510204
# 3.84905660377
# 3.76785714286
# 3.17307692308
# 3.21428571429
# 3.27586206897
# 3.76363636364
# 3.62745098039
# 3.9387755102
# 4.88235294118
# 4.78431372549
# 5.02040816327
# 3.39583333333
# 3.42857142857
# 3.52941176471
# 0.0
# 2.0
# 1.77272727273
# 3.8679245283
# 3.45833333333
# 3.48148148148
# 0.0
# 5.59259259259
# 0.0
# Generation No. : 11
# 3.64285714286
# 3.58333333333
# 3.50847457627
# 3.25
# 3.55102040816
# 3.22448979592
# 3.625
# 3.93617021277
# 3.375
# 3.57894736842
# 3.68421052632
# 3.68965517241
# 5.57894736842
# 6.05555555556
# 6.5
# 4.26086956522
# 3.42857142857
# 4.51851851852
# 4.7358490566
# 4.48979591837
# 4.69491525424
# 3.25423728814
# 3.29310344828
# 3.26666666667
# 3.72881355932
# 3.85964912281
# 3.62745098039
# 6.03636363636
# 6.26785714286
# 6.01818181818
# Generation No. : 12
# 4.22448979592
# 4.5593220339
# 4.20754716981
# 4.98076923077
# 5.5
# 4.96428571429
# 1.2037037037
# 1.26315789474
# 1.10526315789
# 6.59649122807
# 4.91228070175
# 4.70588235294
# 4.06666666667
# 4.70454545455
# 4.82692307692
# 4.67924528302
# 4.77586206897
# 5.61403508772
# 8.22448979592
# 8.50980392157
# 9.8431372549
# 1.03389830508
# 1.2641509434
# 1.11111111111
# 3.12280701754
# 3.46
# 3.63888888889
# 3.45238095238
# 3.4347826087
# 3.82978723404
# Generation No. : 13
# 0.809523809524
# 0.675
# 0.806451612903
# 4.25714285714
# 3.0
# 3.23684210526
# 4.83783783784
# 4.42424242424
# 4.91891891892
# 6.16216216216
# 8.65714285714
# 6.88571428571
# 3.42105263158
# 3.55263157895
# 3.39473684211
# 3.86842105263
# 3.84210526316
# 3.47368421053
# 4.81081081081
# 5.27027027027
# 4.71052631579
# 3.20512820513
# 3.15384615385
# 3.05263157895
# 3.2972972973
# 4.02631578947
# 3.18421052632
# 1.21052631579
# 1.07894736842
# 1.02564102564
# Generation No. : 14
# 3.2972972973
# 3.76315789474
# 3.02631578947
# 3.25
# 3.47368421053
# 3.15789473684
# 3.76923076923
# 3.82051282051
# 4.07894736842
# 3.76923076923
# 3.68421052632
# 3.82051282051
# 0.974358974359
# 1.0
# 0.871794871795
# 3.84210526316
# 3.7027027027
# 4.05555555556
# 4.05882352941
# 4.0
# 2.93939393939
# 0.971428571429
# 0.916666666667
# 0.885714285714
# 5.30303030303
# 4.74285714286
# 4.0
# 4.77142857143
# 6.37142857143
# 5.5
# Generation No. : 15
# 3.36956521739
# 3.10638297872
# 2.91489361702
# 4.02127659574
# 3.74468085106
# 3.93617021277
# 5.53333333333
# 5.13043478261
# 4.55555555556
# 3.85106382979
# 3.72916666667
# 2.89361702128
# 4.5
# 4.14893617021
# 4.82978723404
# 3.46808510638
# 3.89130434783
# 3.89361702128
# 3.11363636364
# 3.31111111111
# 3.34782608696
# 6.62790697674
# 6.61904761905
# 6.14634146341
# 1.04166666667
# 1.29166666667
# 0.851063829787
# 3.91489361702
# 4.02083333333
# 3.36170212766
# Generation No. : 16
# 4.08695652174
# 3.1875
# 3.65957446809
# 1.6170212766
# 2.14893617021
# 1.70833333333
# 6.72340425532
# 7.15217391304
# 7.39130434783
# 3.21276595745
# 3.125
# 3.17021276596
# 5.02173913043
# 4.89361702128
# 4.51063829787
# 0.702127659574
# 0.782608695652
# 0.6875
# 0.0
# 2.0
# 4.0
# 3.2
# 3.13043478261
# 3.22222222222
# 6.23404255319
# 6.13043478261
# 7.21276595745
# 3.8085106383
# 3.17021276596
# 3.53191489362
# Generation No. : 17
# 4.71739130435
# 4.86956521739
# 4.78723404255
# 3.73913043478
# 2.89361702128
# 3.82608695652
# 1.85106382979
# 1.27083333333
# 2.33333333333
# 2.95744680851
# 3.21739130435
# 3.25531914894
# 6.39130434783
# 6.17021276596
# 5.06382978723
# 3.95744680851
# 3.97872340426
# 3.93617021277
# 0.744680851064
# 0.695652173913
# 0.425531914894
# 0.0
# 1.0
# 0.0
# 3.80434782609
# 3.85106382979
# 4.12765957447
# 6.68085106383
# 6.91304347826
# 5.91304347826
# Generation No. : 18
# 5.02173913043
# 4.63829787234
# 4.97826086957
# 3.71739130435
# 3.21739130435
# 4.17021276596
# 3.04255319149
# 3.02127659574
# 3.17021276596
# 4.25531914894
# 3.91489361702
# 3.875
# 0.0
# 0.0
# 0.0
# 0.851063829787
# 0.854166666667
# 0.787234042553
# 3.21276595745
# 3.14893617021
# 3.21276595745
# 5.02127659574
# 4.95744680851
# 5.45652173913
# 4.90697674419
# 3.74468085106
# 3.89361702128
# 5.13043478261
# 6.36170212766
# 6.08510638298
# Generation No. : 19
# 4.4347826087
# 3.6170212766
# 3.83333333333
# 3.93617021277
# 3.55555555556
# 3.60465116279
# 6.47727272727
# 4.95744680851
# 4.95744680851
# 4.89583333333
# 4.71111111111
# 4.91111111111
# 5.60869565217
# 5.12765957447
# 4.42553191489
# 3.51063829787
# 3.06382978723
# 3.44680851064
# 4.8085106383
# 5.14583333333
# 5.0
# 3.31914893617
# 3.14893617021
# 3.04255319149
# 4.82608695652
# 4.93617021277
# 4.74468085106
# 0.0
# 0.0
# 0.0
# Generation No. : 20
# 3.0652173913
# 3.06382978723
# 3.06382978723
# 4.76595744681
# 4.87234042553
# 5.21739130435
# 5.5652173913
# 5.4347826087
# 6.17021276596
# 0.666666666667
# 0.893617021277
# 0.68085106383
# 0.895833333333
# 0.770833333333
# 0.872340425532
# 4.83333333333
# 3.97727272727
# 4.74468085106
# 0.0
# 0.0
# 0.0
# 5.56862745098
# 4.86538461538
# 5.71186440678
# 3.33898305085
# 3.83333333333
# 3.16666666667
# 4.96551724138
# 4.93333333333
# 4.89655172414
# Generation No. : 21
# 4.84482758621
# 5.0
# 4.96610169492
# 3.58333333333
# 3.71666666667
# 3.63333333333
# 3.22413793103
# 3.23728813559
# 3.15
# 4.8813559322
# 4.84745762712
# 4.65
# 5.65573770492
# 5.91525423729
# 6.42372881356
# 4.76271186441
# 4.79310344828
# 4.8275862069
# 0.233333333333
# 0.366666666667
# 0.305084745763
# 7.10169491525
# 7.20338983051
# 7.68965517241
# 0.016393442623
# 0.2
# 0.114754098361
# 10.0588235294
# 8.85714285714
# 8.9387755102
# Generation No. : 22
# 6.54385964912
# 5.76271186441
# 6.37931034483
# 5.8
# 6.94915254237
# 5.72881355932
# 4.7
# 4.71186440678
# 5.30508474576
# 6.10169491525
# 4.93103448276
# 4.93220338983
# 5.01785714286
# 4.82142857143
# 2.16071428571
# 5.1186440678
# 5.1724137931
# 4.93333333333
# 5.08620689655
# 4.68965517241
# 6.13559322034
# 0.254237288136
# 0.229508196721
# 0.233333333333
# 4.95
# 4.86666666667
# 4.89830508475
# 5.53333333333
# 4.84745762712
# 5.91525423729
# Generation No. : 23
# 4.88333333333
# 5.37288135593
# 4.84745762712
# 4.77966101695
# 4.93333333333
# 5.71666666667
# 5.0
# 5.18644067797
# 4.78333333333
# 4.85
# 4.96551724138
# 4.85
# 4.5593220339
# 4.13559322034
# 4.75438596491
# 5.91228070175
# 6.54237288136
# 6.5
# 0.0666666666667
# 0.0666666666667
# 0.0833333333333
# 4.91666666667
# 4.94915254237
# 5.13559322034
# 5.05084745763
# 5.62295081967
# 5.8275862069
# 5.5
# 4.79661016949
# 6.01666666667
# Generation No. : 24
# 5.13559322034
# 4.98333333333
# 5.1186440678
# 4.94915254237
# 5.01666666667
# 5.64406779661
# 4.71186440678
# 4.89473684211
# 5.03389830508
# 4.20338983051
# 4.78947368421
# 4.56896551724
# 0.0
# 0.0
# 0.0
# 6.55
# 6.01785714286
# 5.94827586207
# 0.0
# 1.0
# 3.39130434783
# 6.81034482759
# 6.83050847458
# 6.47457627119
# 4.84482758621
# 4.29310344828
# 4.62068965517
# 5.82142857143
# 6.37288135593
# 5.9
# Generation No. : 25
# 4.29310344828
# 3.67796610169
# 3.87931034483
# 5.57627118644
# 4.89830508475
# 5.46666666667
# 7.9298245614
# 8.81355932203
# 7.84745762712
# 4.27586206897
# 6.01724137931
# 5.83050847458
# 6.34482758621
# 6.27586206897
# 6.1186440678
# 7.61016949153
# 9.64406779661
# 8.55172413793
# 4.8
# 5.96666666667
# 5.66101694915
# 5.52631578947
# 4.06779661017
# 4.62711864407
# 8.46551724138
# 8.91525423729
# 8.03389830508
# 4.72881355932
# 4.83333333333
# 4.86206896552
# Generation No. : 26
# 5.74137931034
# 5.89830508475
# 4.87931034483
# 4.62962962963
# 4.05454545455
# 5.0
# 5.66037735849
# 4.87755102041
# 4.92452830189
# 3.51851851852
# 3.52542372881
# 3.86440677966
# 7.77586206897
# 7.70689655172
# 7.8813559322
# 5.46666666667
# 4.66101694915
# 6.13559322034
# 5.77192982456
# 5.53703703704
# 6.01754385965
# 0.0
# 0.0
# 0.0
# 8.25
# 7.63265306122
# 8.23529411765
# 4.90909090909
# 5.5
# 4.8679245283
# Generation No. : 27
# 5.17647058824
# 6.34615384615
# 6.38888888889
# 3.65517241379
# 4.79310344828
# 4.75862068966
# 4.78947368421
# 5.55172413793
# 5.89830508475
# 4.50847457627
# 4.81355932203
# 4.94642857143
# 4.8431372549
# 4.73684210526
# 4.85964912281
# 4.85454545455
# 5.69090909091
# 6.40350877193
# 7.49152542373
# 6.93220338983
# 6.37288135593
# 8.53448275862
# 8.72881355932
# 8.23636363636
# 5.85714285714
# 5.47272727273
# 4.72
# 4.42372881356
# 3.82352941176
# 4.92452830189
# Generation No. : 28
# 4.09433962264
# 5.32653061224
# 3.8
# 4.76923076923
# 5.18965517241
# 5.77966101695
# 4.95744680851
# 5.5
# 5.4693877551
# 4.82142857143
# 4.85454545455
# 4.85964912281
# 4.85964912281
# 4.7
# 4.94915254237
# 4.84210526316
# 5.83333333333
# 4.90196078431
# 6.35294117647
# 5.5
# 5.375
# 4.73469387755
# 4.66666666667
# 4.90196078431
# 5.0
# 5.58181818182
# 4.94545454545
# 7.7
# 7.95918367347
# 8.0
# Generation No. : 29
# 5.53448275862
# 5.51666666667
# 4.89473684211
# 4.89473684211
# 5.38888888889
# 5.90566037736
# 1.85714285714
# 1.96078431373
# 1.96610169492
# 3.94915254237
# 3.54716981132
# 3.85964912281
# 3.39285714286
# 4.0
# 3.94642857143
# 5.36666666667
# 5.64406779661
# 4.7962962963
# 3.96428571429
# 6.0
# 7.15555555556
# 6.9
# 5.70833333333
# 5.68085106383
# 6.02380952381
# 5.02127659574
# 4.98305084746
# 6.14
# 5.28813559322
# 5.26315789474
# Generation No. : 30
# 4.98148148148
# 5.0
# 4.9649122807
# 3.75
# 5.60377358491
# 3.77358490566
# 1.76363636364
# 1.89285714286
# 1.89285714286
# 5.40350877193
# 5.43636363636
# 5.85714285714
# 4.8
# 4.82142857143
# 4.91379310345
# 5.48780487805
# 4.63414634146
# 2.64444444444
# 5.15094339623
# 5.27777777778
# 4.29411764706
# 4.87719298246
# 5.41818181818
# 4.9375
# 4.92
# 5.875
# 6.55319148936
# 5.73469387755
# 6.31914893617
# 5.84782608696
# Generation No. : 31
# 1.88235294118
# 1.77083333333
# 1.73076923077
# 4.8
# 5.64705882353
# 4.4375
# 4.82352941176
# 5.64285714286
# 4.84745762712
# 4.96610169492
# 5.47272727273
# 4.94
# 3.64814814815
# 3.0487804878
# 3.79069767442
# 3.57692307692
# 3.85964912281
# 4.37037037037
# 4.87719298246
# 4.86206896552
# 5.15
# 5.63157894737
# 4.91304347826
# 4.8275862069
# 4.93220338983
# 4.78181818182
# 4.89655172414
# 4.91666666667
# 5.56363636364
# 5.05454545455
# Generation No. : 32
# 7.73469387755
# 7.69090909091
# 8.29090909091
# 5.76595744681
# 4.94339622642
# 5.77586206897
# 4.86666666667
# 4.87719298246
# 4.87931034483
# 5.41818181818
# 4.34545454545
# 4.6
# 3.82608695652
# 2.97142857143
# 3.65714285714
# 5.53846153846
# 6.02857142857
# 5.36538461538
# 0.0
# 0.0
# 0.0
# 5.12
# 3.0
# 4.66666666667
# 4.94915254237
# 4.86206896552
# 4.87804878049
# 5.37037037037
# 5.12280701754
# 5.14035087719
# Generation No. : 33
# 5.5625
# 3.80487804878
# 3.66666666667
# 4.84482758621
# 4.94736842105
# 6.23728813559
# 4.84482758621
# 5.53333333333
# 5.12068965517
# 7.43859649123
# 7.53448275862
# 7.72413793103
# 3.40350877193
# 3.91525423729
# 3.77777777778
# 5.47916666667
# 4.89795918367
# 5.56603773585
# 0.0
# 0.0
# 0.0
# 5.88679245283
# 6.2641509434
# 4.56603773585
# 4.67307692308
# 6.41509433962
# 3.9387755102
# 3.58139534884
# 3.84090909091
# 3.57446808511
# Generation No. : 34
#
# Evolution time: 11540.000000 s
#
#  .......... End of Evolution :D ..........
# C:\Anaconda2\lib\site-packages\matplotlib\backend_bases.py:2435: MatplotlibDeprecationWarning: Using default event loop until function specific to this GUI is implemented
#   warnings.warn(str, mplDeprecation)
# Save populations genomes and evolution configuration ? : [1:Yes; 0: No]1
# Press ENTER to save in evoLog_try6.pck file or input the number of the desired saving file:                                   8
# ...Saving evolutionary data...
#
# Do you want to : [1:Simulate evolved agents ; 0: QUIT]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\IVAN\Desktop\evoBoids\evoBoids Code\evoBoids.py in <module>()
#     448
#     449         for index,val in np.ndenumerate(gens2show):
# --> 450             print "Simulating generation No. %d" %val
#     451             simuParams = np.array([0,visualON,timeOutT], dtype= 'float64')
#     452             simuParams = np.insert(simuParams,1,bestIndPerGen[val,:]).tolist() # insert in index=1 of simuParams
#
# C:\Users\IVAN\Desktop\evoBoids\evoBoids Code\evoBoids.py in main()
#     426         lastPop = popHist[...,-1]
#     427
# --> 428         # Store Fitness Plotting Data
#     429         fitPlotData = [maxFitHist , avgFitHist , minFitHist]
#     430
#
# ValueError: invalid literal for int() with base 10: ''

# %%
import numpy as np 
import matplotlib.pyplot as plt
import pickle
import os

">>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Import Simulation Script <<<<<<<<<<<<<<<<<<<<<<<<<<<<<"   

filepath='C:\Users\IVAN\Desktop\evoBoids\evoBoids Code'
os.chdir(filepath)
import boidsSimu # Boid simulator library

"Import populations genomes and evolution configuration"
f = open('C:\Users\IVAN\Desktop\evoBoids\evoBoids Code\evoLog\evoLog_try5.pckl')
lastPop,bestIndPerAll,evoConfig,fitHist,fitPlotData,bestIndPerGen,ellapsedT= pickle.load(f)
f.close()
maxFitHist , avgFitHist , minFitHist = fitPlotData
popSize, generations,selectMethod,elitism,crossProb,mutProb,\
numRept,timeOutT,fitWeights = evoConfig
# print "Evolution time : %f \n" %ellapsedT

">>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Plot Fitnesses <<<<<<<<<<<<<<<<<<<<<<<<<<<><<<<<<" 
plt.close(2)
plt.figure(2)
plt.xlabel('Genera|tions')
plt.ylabel('Fitness')
plt.title('Average Fitness per Evolved Generation')
plt.grid(True)
plt.gca().set_xlim(0,avgFitHist.shape[1]-1)
plt.pause(0.05)
plt.ion()

plotGen = np.arange(avgFitHist.shape[1])
plt.plot(plotGen,maxFitHist[0,0::],marker = 'o',markerfacecolor = 'k',ms = 6.0, \
                                              color= 'm', linewidth = 2.5, label = "Max.Fitness")  
plt.plot(plotGen,avgFitHist[0,0::],marker = 'o',markerfacecolor = 'k',ms = 6.0, \
                                              color= 'g', linewidth = 2.5, label = "Avg.Fitness")  
plt.plot(plotGen,minFitHist[0,0::],marker = 'o',markerfacecolor = 'k',ms = 6.0, \
                                              color= 'r', linewidth = 2.5, label = "Min.Fitness")  

plt.legend(bbox_to_anchor=(0,1.02,1,0.15),ncol=3, mode="expand", borderaxespad=0.)
plt.gcf().tight_layout(rect=[0,0,1,0.925])
# bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.0)
plt.pause(0.05)
plt.show()

">>>>>>>>>>>>>>>>>>>>>>>>>>> Simulate best of each generation <<<<<<<<<<<<<<<<<<<<<<<<<"
simu = raw_input("Simulate Agents: [Enter: Yes ;0: No]")

if not simu:
    # Configure Simulation params.
    generation = avgFitHist.shape[1]-2
    percGenDisplay = 0.2
    visualON = 1

    # Obtain which generations to simulate
    if int((generation+2)*percGenDisplay):gens2show = np.arange(0,generation+2,int((generation+2)*percGenDisplay))
    else: gens2show = np.arange(0,(generation+2),1)

    if (generation+1) not in gens2show.tolist():
        gens2show = np.concatenate((gens2show,[generation+1]))
        
    for index,val in np.ndenumerate(gens2show):
        cancel = raw_input("\nInput: [Enter: to simulate generation %d ; 0: Cancel simulation ..." %val)
        if cancel: break
        print "Simulating generation No. %d" %val
        
        simuParams = np.array([0,visualON,timeOutT], dtype= 'float64') 
        simuParams = np.insert(simuParams,1,bestIndPerGen[val,:]).tolist() # insert in index=1 of simuParams
        fitVals = boidsSimu.main(simuParams)
        print "Fitness values : "
        print "interCollV  medGRadiiV  deltaTV  numATgoalV"
        print fitVals
        print "Total fitness : %f \n" %fitWeights.dot(fitVals.transpose())

# {    ">>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Simulate IDEAL AGENT <<<<<<<<<<<<<<<<<<<<<<<<<<"
#     "IDEAL Agent, only for DEBUGG"
#     casualAgentR = 10.0
#     idealInd = np.array([casualAgentR*10, 4.0/100, 23.0/100, 90.0/100, casualAgentR*5, 10])
#     x = 1
#     timeOutT = 10
#     while x: 
#         ideal = raw_input("Enter: to simulate IDEAL AGENT ; 0: Cancel simulation ...")
#         if ideal: break
            
#         simuParams = np.array([0,visualON,timeOutT], dtype= 'float64') 
#         simuParams = np.insert(simuParams,1,idealInd).tolist() # insert in index=1 of simuParams
#         fitVals = boidsSimu.main(simuParams)
#         print "Fitness values : "
#         print "interCollV  medGRadiiV  deltaTV  numATgoalV"
#         print fitVals
#         print "Total fitness : %f \n" %fitWeights.dot(fitVals.transpose())}
        

raw_input("\n... Enter to Close Plot ...")
plt.close(2)
